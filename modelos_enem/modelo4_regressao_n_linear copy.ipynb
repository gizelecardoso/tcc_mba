# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme()

# %%
enem = pd.read_csv('../src/enem_total_dum_pad.csv')

enem.set_index('NU_INSCRICAO', drop=True, inplace=True)

enem.head()
# Out:
#               IN_BRAILLE  IN_AMPLIADA_18  IN_AMPLIADA_24  IN_LEDOR  IN_ACESSO  \
# NU_INSCRICAO
# 190001237802           0               0               0         0          0
# 190001421548           0               0               0         0          0
# 190001592266           0               0               0         0          0
# 190001475147           0               0               0         0          0
# 190001867756           0               0               0         0          0
#
#               IN_TRANSCRICAO  IN_LIBRAS  APPROVED_ADM  APPROVED_MED  \
# NU_INSCRICAO
# 190001237802               0          0             1             0
# 190001421548               0          0             0             0
# 190001592266               0          0             0             0
# 190001475147               0          0             0             0
# 190001867756               0          0             0             0
#
#               NU_ANO_2019  ...  NU_NOTA_LC  NU_NOTA_MT  NU_NOTA_COMP1  \
# NU_INSCRICAO               ...
# 190001237802            1  ...    0.715873    1.475362       1.531819
# 190001421548            1  ...   -0.506077    0.694142       0.583889
# 190001592266            1  ...   -0.596521   -0.387986      -0.364042
# 190001475147            1  ...   -2.230278   -0.593970      -0.364042
# 190001867756            1  ...   -1.587552   -0.350016      -0.364042
#
#               NU_NOTA_COMP2  NU_NOTA_COMP3  NU_NOTA_COMP4  NU_NOTA_COMP5  \
# NU_INSCRICAO
# 190001237802      -0.455473       1.905869       1.678562       1.765516
# 190001421548      -0.455473      -0.229759       1.276303      -0.740683
# 190001592266      -1.735008      -0.229759      -0.332733      -1.814768
# 190001475147      -0.455473      -0.229759      -0.332733      -1.456740
# 190001867756      -1.735008      -1.511136      -1.137250      -1.814768
#
#               NU_NOTA_REDACAO      Q005  NU_NOTA_MEDIA
# NU_INSCRICAO
# 190001237802         1.638358 -0.610414       1.079994
# 190001421548        -0.091095 -0.610414       0.063155
# 190001592266        -1.421443  0.854579       0.064319
# 190001475147        -0.756269  0.122083      -1.211875
# 190001867756        -2.086618 -0.610414      -1.380377
#
# [5 rows x 674 columns]
